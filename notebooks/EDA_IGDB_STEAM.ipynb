# %% [markdown]
# # IMT2200 — Proyecto: Conexión y Exploración IGDB API
# ## Descarga y exploración inicial de datos de videojuegos (IGDB)
#
# **Autor:** Andres Gonzales
# **Curso:** IMT2200 - Introducción a Ciencia de Datos (2025-2)
#
# ---
#
# ### ⚙️ Descripción
# Este notebook conecta directamente a la **API de IGDB**, descarga un conjunto de juegos con campos relevantes y los guarda en `data/igdb_games.csv`.
#
# Luego, realiza una **limpieza básica y un análisis exploratorio inicial** (EDA).
#
# > 💡 El objetivo es dejar automatizado el flujo de adquisición de datos para integrarlo después con la API de Steam/SteamCharts.

# %% [markdown]
# ## 1. Configuración e importación de librerías

# %%
import os
import requests
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Configuraciones generales
pd.set_option('display.max_columns', 50)
pd.set_option('display.width', 120)

# Crear carpeta data si no existe
os.makedirs('data', exist_ok=True)

# %% [markdown]
# ## 2. Autenticación y parámetros de la API IGDB
#
# Pega tus credenciales de forma local (no las subas al repositorio público).

# %%
client_id = "uksbpu6oftndjav5xb8wzk1a8j63fm"
client_secret = "zj3i336wtqr4qc9mizsubfcpi32xlt"  # <-- pega el secreto real de Twitch aquí

url = "https://id.twitch.tv/oauth2/token"
params = {
    "client_id": client_id,
    "client_secret": client_secret,
    "grant_type": "client_credentials"
}

resp = requests.post(url, params=params)
print(resp.json())
# Out:
# {'access_token': 'lcw4wgqn7ltr8rr0b85l65rtawn2dq', 'expires_in': 5314779, 'token_type': 'bearer'}

# %% [markdown]
# ## 3. Descarga de datos desde la API

# %%
import os, time, json, pathlib, datetime as dt, requests, pandas as pd

CLIENT_ID     = "lbosp4quzjq9oe0nhgd7k291j7lf7y"
CLIENT_SECRET = "0qlq0q84p2zfzucsxa0ocgg167cnsb"

RAW_DIR   = pathlib.Path("datos/no_limpios");  RAW_DIR.mkdir(parents=True, exist_ok=True)
CLEAN_DIR = pathlib.Path("datos/limpios");     CLEAN_DIR.mkdir(parents=True, exist_ok=True)

def epoch(d: dt.date) -> int:
    return int(dt.datetime(d.year, d.month, d.day, tzinfo=dt.timezone.utc).timestamp())

def igdb_token():
    r = requests.post(
        "https://id.twitch.tv/oauth2/token",
        data={"client_id": CLIENT_ID,
              "client_secret": CLIENT_SECRET,
              "grant_type": "client_credentials"},
        timeout=10)
    r.raise_for_status()
    return r.json()["access_token"]

# Descargar juegos IGDB (último año) 
def fetch_igdb_last_year():
    today  = dt.date.today()
    start  = today.replace(year=today.year - 1)            # hace 12 meses
    ini, fin = epoch(start), epoch(today)

    token = igdb_token()
    hdrs  = {"Client-ID": CLIENT_ID, "Authorization": f"Bearer {token}"}
    api   = "https://api.igdb.com/v4/games"

    STEP = 500
    query = f"""
    fields id,name,first_release_date,
           genres.name,platforms.name,
           rating,rating_count,aggregated_rating,total_rating,
           follows,popularity,hypes,
           involved_companies.company.name,
           involved_companies.developer,
           involved_companies.publisher,
           external_games;
    where first_release_date >= {ini}
      & first_release_date <  {fin};
    limit {STEP};
    offset %d;
    """

    data, offset = [], 0
    while True:
        batch = requests.post(api, headers=hdrs, data=query % offset, timeout=30).json()
        if not batch:
            break
        data.extend(batch)
        offset += STEP
        print(f"IGDB +{len(batch):3d}  (offset {offset})")
        time.sleep(0.35)
    RAW_DIR.joinpath("igdb_last_year.json").write_text(json.dumps(data, indent=2))
    return data, hdrs

def steam_ids_from_igdb(igdb_data, hdrs):
    api_ext = "https://api.igdb.com/v4/external_games"
    CHUNK, mapping = 200, {}
    ids_list = [g["id"] for g in igdb_data]
    for chunk in [ids_list[i:i+CHUNK] for i in range(0, len(ids_list), CHUNK)]:
        q = f"fields game, uid, category; where game = ({','.join(map(str,chunk))}) & category = 1;"  # 1=Steam
        for eg in requests.post(api_ext, headers=hdrs, data=q, timeout=30).json():
            mapping[eg["game"]] = int(eg["uid"])
        time.sleep(0.35)
    RAW_DIR.joinpath("steam_appids_last_year.json").write_text(json.dumps(mapping, indent=2))
    return mapping

def fetch_steam(appids, throttle=0.25):
    players, details = {}, {}
    for aid in appids:
        p = requests.get(
            "https://api.steampowered.com/ISteamUserStats/GetNumberOfCurrentPlayers/v1/",
            params={"appid": aid}, timeout=10).json()
        players[aid] = p["response"].get("player_count", 0)

        d = requests.get(
            "https://store.steampowered.com/api/appdetails",
            params={"appids": aid, "cc": "us", "l": "en"}, timeout=10).json()
        if d[str(aid)]["success"]:
            details[aid] = d[str(aid)]["data"]

        print(f"Steam {aid} OK")
        time.sleep(throttle)
    RAW_DIR.joinpath("steam_players_last_year.json").write_text(json.dumps(players, indent=2))
    RAW_DIR.joinpath("steam_details_last_year.json").write_text(json.dumps(details, indent=2))
    return players, details

def save_csv_igdb(games):
    df = pd.json_normalize(games, sep="_")
    df.to_csv(CLEAN_DIR / "igdb_games_last_year.csv", index=False)

def save_csv_steam(players, details):
    df_players = pd.Series(players, name="player_count").to_frame()
    df_details = pd.json_normalize(details).set_index("steam_appid")
    df_players.join(df_details, how="left").to_csv(CLEAN_DIR / "steam_last_year.csv")
if __name__ == "__main__":
    igdb_raw, hdrs = fetch_igdb_last_year()
    steam_map      = steam_ids_from_igdb(igdb_raw, hdrs)

    players, details = fetch_steam(list(steam_map.values()))
    save_csv_igdb(igdb_raw)
    save_csv_steam(players, details)

    print("\n✅ Proceso completo: CSV listos en  datos/limpios/")
# Out:
# IGDB +  1  (offset 500)
# IGDB +  1  (offset 1000)
# IGDB +  1  (offset 1500)
# IGDB +  1  (offset 2000)
# IGDB +  1  (offset 2500)
# IGDB +  1  (offset 3000)
# IGDB +  1  (offset 3500)
# IGDB +  1  (offset 4000)
# IGDB +  1  (offset 4500)
# IGDB +  1  (offset 5000)
# IGDB +  1  (offset 5500)
# IGDB +  1  (offset 6000)
# IGDB +  1  (offset 6500)
# IGDB +  1  (offset 7000)
# IGDB +  1  (offset 7500)
# IGDB +  1  (offset 8000)
# IGDB +  1  (offset 8500)
# IGDB +  1  (offset 9000)
# IGDB +  1  (offset 9500)
# IGDB +  1  (offset 10000)
# IGDB +  1  (offset 10500)
# IGDB +  1  (offset 11000)
# IGDB +  1  (offset 11500)
# IGDB +  1  (offset 12000)
# IGDB +  1  (offset 12500)
# IGDB +  1  (offset 13000)
# IGDB +  1  (offset 13500)
# IGDB +  1  (offset 14000)
# IGDB +  1  (offset 14500)
# IGDB +  1  (offset 15000)
# IGDB +  1  (offset 15500)
# IGDB +  1  (offset 16000)
# IGDB +  1  (offset 16500)
# IGDB +  1  (offset 17000)
# IGDB +  1  (offset 17500)
# IGDB +  1  (offset 18000)
# IGDB +  1  (offset 18500)
# IGDB +  1  (offset 19000)
# IGDB +  1  (offset 19500)
# IGDB +  1  (offset 20000)
# IGDB +  1  (offset 20500)
# IGDB +  1  (offset 21000)
# IGDB +  1  (offset 21500)
# IGDB +  1  (offset 22000)
# IGDB +  1  (offset 22500)
# IGDB +  1  (offset 23000)
# IGDB +  1  (offset 23500)
# IGDB +  1  (offset 24000)
# IGDB +  1  (offset 24500)
# IGDB +  1  (offset 25000)
# IGDB +  1  (offset 25500)
# IGDB +  1  (offset 26000)
# IGDB +  1  (offset 26500)
# IGDB +  1  (offset 27000)
# IGDB +  1  (offset 27500)
# IGDB +  1  (offset 28000)
# IGDB +  1  (offset 28500)
# IGDB +  1  (offset 29000)
# IGDB +  1  (offset 29500)
# IGDB +  1  (offset 30000)
# IGDB +  1  (offset 30500)
# IGDB +  1  (offset 31000)
# IGDB +  1  (offset 31500)
# IGDB +  1  (offset 32000)
# IGDB +  1  (offset 32500)
# IGDB +  1  (offset 33000)
# IGDB +  1  (offset 33500)
# IGDB +  1  (offset 34000)
# IGDB +  1  (offset 34500)
# IGDB +  1  (offset 35000)
# IGDB +  1  (offset 35500)
# IGDB +  1  (offset 36000)
# IGDB +  1  (offset 36500)
# IGDB +  1  (offset 37000)
# IGDB +  1  (offset 37500)
# IGDB +  1  (offset 38000)
# IGDB +  1  (offset 38500)
# IGDB +  1  (offset 39000)
# IGDB +  1  (offset 39500)
# IGDB +  1  (offset 40000)
# IGDB +  1  (offset 40500)
# IGDB +  1  (offset 41000)
# IGDB +  1  (offset 41500)
# IGDB +  1  (offset 42000)
# IGDB +  1  (offset 42500)
# IGDB +  1  (offset 43000)
# IGDB +  1  (offset 43500)
# IGDB +  1  (offset 44000)
# IGDB +  1  (offset 44500)
# IGDB +  1  (offset 45000)
# IGDB +  1  (offset 45500)
# IGDB +  1  (offset 46000)
# IGDB +  1  (offset 46500)
# IGDB +  1  (offset 47000)
# IGDB +  1  (offset 47500)
# IGDB +  1  (offset 48000)
# IGDB +  1  (offset 48500)
# IGDB +  1  (offset 49000)
# IGDB +  1  (offset 49500)
# IGDB +  1  (offset 50000)
# IGDB +  1  (offset 50500)
# IGDB +  1  (offset 51000)
# IGDB +  1  (offset 51500)
# IGDB +  1  (offset 52000)
# IGDB +  1  (offset 52500)
# IGDB +  1  (offset 53000)
# IGDB +  1  (offset 53500)
# IGDB +  1  (offset 54000)
# IGDB +  1  (offset 54500)
# IGDB +  1  (offset 55000)
# IGDB +  1  (offset 55500)
# IGDB +  1  (offset 56000)
# IGDB +  1  (offset 56500)
# IGDB +  1  (offset 57000)
# IGDB +  1  (offset 57500)
# IGDB +  1  (offset 58000)
# IGDB +  1  (offset 58500)
# IGDB +  1  (offset 59000)
# IGDB +  1  (offset 59500)
# IGDB +  1  (offset 60000)
# IGDB +  1  (offset 60500)
# IGDB +  1  (offset 61000)
# IGDB +  1  (offset 61500)
# IGDB +  1  (offset 62000)
# IGDB +  1  (offset 62500)
# IGDB +  1  (offset 63000)
# IGDB +  1  (offset 63500)
# IGDB +  1  (offset 64000)
# IGDB +  1  (offset 64500)
# IGDB +  1  (offset 65000)
# IGDB +  1  (offset 65500)
# IGDB +  1  (offset 66000)
# IGDB +  1  (offset 66500)
# IGDB +  1  (offset 67000)
# IGDB +  1  (offset 67500)
# IGDB +  1  (offset 68000)
# IGDB +  1  (offset 68500)
# IGDB +  1  (offset 69000)
# IGDB +  1  (offset 69500)
# IGDB +  1  (offset 70000)
# IGDB +  1  (offset 70500)
# IGDB +  1  (offset 71000)
# IGDB +  1  (offset 71500)
# IGDB +  1  (offset 72000)
# IGDB +  1  (offset 72500)
# IGDB +  1  (offset 73000)
# IGDB +  1  (offset 73500)
# IGDB +  1  (offset 74000)
# IGDB +  1  (offset 74500)
# IGDB +  1  (offset 75000)
# IGDB +  1  (offset 75500)
# IGDB +  1  (offset 76000)
# IGDB +  1  (offset 76500)
# IGDB +  1  (offset 77000)
# IGDB +  1  (offset 77500)
# IGDB +  1  (offset 78000)
# IGDB +  1  (offset 78500)
# IGDB +  1  (offset 79000)
# IGDB +  1  (offset 79500)
# IGDB +  1  (offset 80000)
# IGDB +  1  (offset 80500)
# IGDB +  1  (offset 81000)
# IGDB +  1  (offset 81500)
# IGDB +  1  (offset 82000)
# IGDB +  1  (offset 82500)
# IGDB +  1  (offset 83000)
# IGDB +  1  (offset 83500)
# IGDB +  1  (offset 84000)
# IGDB +  1  (offset 84500)
# IGDB +  1  (offset 85000)
# IGDB +  1  (offset 85500)
# IGDB +  1  (offset 86000)
# IGDB +  1  (offset 86500)
# IGDB +  1  (offset 87000)
# IGDB +  1  (offset 87500)
# IGDB +  1  (offset 88000)
# IGDB +  1  (offset 88500)
# IGDB +  1  (offset 89000)
# IGDB +  1  (offset 89500)
# IGDB +  1  (offset 90000)
# IGDB +  1  (offset 90500)
# IGDB +  1  (offset 91000)
# IGDB +  1  (offset 91500)
# IGDB +  1  (offset 92000)
# IGDB +  1  (offset 92500)
# IGDB +  1  (offset 93000)
# IGDB +  1  (offset 93500)
# IGDB +  1  (offset 94000)
# IGDB +  1  (offset 94500)
# IGDB +  1  (offset 95000)
# IGDB +  1  (offset 95500)
# IGDB +  1  (offset 96000)
# IGDB +  1  (offset 96500)
# IGDB +  1  (offset 97000)
# IGDB +  1  (offset 97500)
# IGDB +  1  (offset 98000)
# IGDB +  1  (offset 98500)
# IGDB +  1  (offset 99000)
# IGDB +  1  (offset 99500)
# IGDB +  1  (offset 100000)
# IGDB +  1  (offset 100500)
# IGDB +  1  (offset 101000)
# IGDB +  1  (offset 101500)
# IGDB +  1  (offset 102000)
# IGDB +  1  (offset 102500)
# IGDB +  1  (offset 103000)
# IGDB +  1  (offset 103500)
# IGDB +  1  (offset 104000)
# IGDB +  1  (offset 104500)
# IGDB +  1  (offset 105000)
# IGDB +  1  (offset 105500)
# IGDB +  1  (offset 106000)
# IGDB +  1  (offset 106500)
# IGDB +  1  (offset 107000)
# IGDB +  1  (offset 107500)
# IGDB +  1  (offset 108000)
# IGDB +  1  (offset 108500)
# IGDB +  1  (offset 109000)
# IGDB +  1  (offset 109500)
# IGDB +  1  (offset 110000)
# IGDB +  1  (offset 110500)
# IGDB +  1  (offset 111000)
# IGDB +  1  (offset 111500)
# IGDB +  1  (offset 112000)
# IGDB +  1  (offset 112500)
# IGDB +  1  (offset 113000)
# IGDB +  1  (offset 113500)
# IGDB +  1  (offset 114000)
# IGDB +  1  (offset 114500)
# IGDB +  1  (offset 115000)
# IGDB +  1  (offset 115500)
# IGDB +  1  (offset 116000)
# IGDB +  1  (offset 116500)
# IGDB +  1  (offset 117000)
# IGDB +  1  (offset 117500)
# IGDB +  1  (offset 118000)
# IGDB +  1  (offset 118500)
# IGDB +  1  (offset 119000)
# IGDB +  1  (offset 119500)
# IGDB +  1  (offset 120000)
# IGDB +  1  (offset 120500)
# IGDB +  1  (offset 121000)
# IGDB +  1  (offset 121500)
# IGDB +  1  (offset 122000)
# IGDB +  1  (offset 122500)
# IGDB +  1  (offset 123000)
# IGDB +  1  (offset 123500)
# IGDB +  1  (offset 124000)
# IGDB +  1  (offset 124500)
# IGDB +  1  (offset 125000)
# IGDB +  1  (offset 125500)
# IGDB +  1  (offset 126000)
# IGDB +  1  (offset 126500)
# IGDB +  1  (offset 127000)
# IGDB +  1  (offset 127500)
# IGDB +  1  (offset 128000)
# IGDB +  1  (offset 128500)
# IGDB +  1  (offset 129000)
# IGDB +  1  (offset 129500)
# IGDB +  1  (offset 130000)
# IGDB +  1  (offset 130500)
# IGDB +  1  (offset 131000)
# IGDB +  1  (offset 131500)
# IGDB +  1  (offset 132000)
# IGDB +  1  (offset 132500)
# IGDB +  1  (offset 133000)
# IGDB +  1  (offset 133500)
# IGDB +  1  (offset 134000)
# IGDB +  1  (offset 134500)
# IGDB +  1  (offset 135000)
# IGDB +  1  (offset 135500)
# IGDB +  1  (offset 136000)
# IGDB +  1  (offset 136500)
# IGDB +  1  (offset 137000)
# IGDB +  1  (offset 137500)
# IGDB +  1  (offset 138000)
# IGDB +  1  (offset 138500)
# IGDB +  1  (offset 139000)
# IGDB +  1  (offset 139500)
# IGDB +  1  (offset 140000)
# IGDB +  1  (offset 140500)
# IGDB +  1  (offset 141000)
# IGDB +  1  (offset 141500)
# IGDB +  1  (offset 142000)
# IGDB +  1  (offset 142500)
# IGDB +  1  (offset 143000)
# IGDB +  1  (offset 143500)
# IGDB +  1  (offset 144000)
# IGDB +  1  (offset 144500)
# IGDB +  1  (offset 145000)
# IGDB +  1  (offset 145500)
# IGDB +  1  (offset 146000)
# IGDB +  1  (offset 146500)
# IGDB +  1  (offset 147000)
# IGDB +  1  (offset 147500)
# IGDB +  1  (offset 148000)
# IGDB +  1  (offset 148500)
# IGDB +  1  (offset 149000)
# IGDB +  1  (offset 149500)
# IGDB +  1  (offset 150000)
# IGDB +  1  (offset 150500)
# IGDB +  1  (offset 151000)
# IGDB +  1  (offset 151500)
# IGDB +  1  (offset 152000)
# IGDB +  1  (offset 152500)
# IGDB +  1  (offset 153000)
# IGDB +  1  (offset 153500)
# IGDB +  1  (offset 154000)
# IGDB +  1  (offset 154500)
# IGDB +  1  (offset 155000)
# IGDB +  1  (offset 155500)
# IGDB +  1  (offset 156000)
# IGDB +  1  (offset 156500)
# IGDB +  1  (offset 157000)
# IGDB +  1  (offset 157500)
# IGDB +  1  (offset 158000)
# IGDB +  1  (offset 158500)
# IGDB +  1  (offset 159000)
# IGDB +  1  (offset 159500)
# IGDB +  1  (offset 160000)
# IGDB +  1  (offset 160500)
# IGDB +  1  (offset 161000)
# IGDB +  1  (offset 161500)
# IGDB +  1  (offset 162000)
# IGDB +  1  (offset 162500)
# IGDB +  1  (offset 163000)
# IGDB +  1  (offset 163500)
# IGDB +  1  (offset 164000)
# IGDB +  1  (offset 164500)
# IGDB +  1  (offset 165000)
# IGDB +  1  (offset 165500)
# IGDB +  1  (offset 166000)
# IGDB +  1  (offset 166500)
# IGDB +  1  (offset 167000)
# IGDB +  1  (offset 167500)
# IGDB +  1  (offset 168000)
# IGDB +  1  (offset 168500)
# IGDB +  1  (offset 169000)
# IGDB +  1  (offset 169500)
# IGDB +  1  (offset 170000)
# IGDB +  1  (offset 170500)
# IGDB +  1  (offset 171000)
# IGDB +  1  (offset 171500)
# IGDB +  1  (offset 172000)
# IGDB +  1  (offset 172500)
# IGDB +  1  (offset 173000)
# IGDB +  1  (offset 173500)
# IGDB +  1  (offset 174000)
# IGDB +  1  (offset 174500)
# IGDB +  1  (offset 175000)
# IGDB +  1  (offset 175500)
# IGDB +  1  (offset 176000)
# IGDB +  1  (offset 176500)
# IGDB +  1  (offset 177000)
# IGDB +  1  (offset 177500)
# IGDB +  1  (offset 178000)
# IGDB +  1  (offset 178500)
# IGDB +  1  (offset 179000)
# IGDB +  1  (offset 179500)
# IGDB +  1  (offset 180000)
# IGDB +  1  (offset 180500)
# IGDB +  1  (offset 181000)
# IGDB +  1  (offset 181500)
# IGDB +  1  (offset 182000)
# IGDB +  1  (offset 182500)
# IGDB +  1  (offset 183000)
# IGDB +  1  (offset 183500)
# IGDB +  1  (offset 184000)
# IGDB +  1  (offset 184500)
# IGDB +  1  (offset 185000)
# IGDB +  1  (offset 185500)
# IGDB +  1  (offset 186000)
# IGDB +  1  (offset 186500)
# IGDB +  1  (offset 187000)
# IGDB +  1  (offset 187500)
# IGDB +  1  (offset 188000)
# IGDB +  1  (offset 188500)
# IGDB +  1  (offset 189000)
# IGDB +  1  (offset 189500)
# IGDB +  1  (offset 190000)
# IGDB +  1  (offset 190500)
# IGDB +  1  (offset 191000)
# IGDB +  1  (offset 191500)
# IGDB +  1  (offset 192000)
# IGDB +  1  (offset 192500)
# IGDB +  1  (offset 193000)
# IGDB +  1  (offset 193500)
# IGDB +  1  (offset 194000)
# IGDB +  1  (offset 194500)
# IGDB +  1  (offset 195000)
# IGDB +  1  (offset 195500)
# IGDB +  1  (offset 196000)
# IGDB +  1  (offset 196500)
# IGDB +  1  (offset 197000)
# IGDB +  1  (offset 197500)
# IGDB +  1  (offset 198000)
# IGDB +  1  (offset 198500)
# IGDB +  1  (offset 199000)
# IGDB +  1  (offset 199500)
# IGDB +  1  (offset 200000)
# IGDB +  1  (offset 200500)
# IGDB +  1  (offset 201000)
# IGDB +  1  (offset 201500)
# IGDB +  1  (offset 202000)
# IGDB +  1  (offset 202500)
# IGDB +  1  (offset 203000)
# IGDB +  1  (offset 203500)
# IGDB +  1  (offset 204000)
# IGDB +  1  (offset 204500)
# IGDB +  1  (offset 205000)
# IGDB +  1  (offset 205500)
# IGDB +  1  (offset 206000)
# IGDB +  1  (offset 206500)
# IGDB +  1  (offset 207000)
# IGDB +  1  (offset 207500)
# IGDB +  1  (offset 208000)
# IGDB +  1  (offset 208500)
# IGDB +  1  (offset 209000)
# IGDB +  1  (offset 209500)
# IGDB +  1  (offset 210000)
# IGDB +  1  (offset 210500)
# IGDB +  1  (offset 211000)
# IGDB +  1  (offset 211500)
# IGDB +  1  (offset 212000)
# IGDB +  1  (offset 212500)
# IGDB +  1  (offset 213000)
# IGDB +  1  (offset 213500)
# IGDB +  1  (offset 214000)
# IGDB +  1  (offset 214500)
# IGDB +  1  (offset 215000)
# IGDB +  1  (offset 215500)
# IGDB +  1  (offset 216000)
# IGDB +  1  (offset 216500)
# IGDB +  1  (offset 217000)
# IGDB +  1  (offset 217500)
# IGDB +  1  (offset 218000)
# IGDB +  1  (offset 218500)
# IGDB +  1  (offset 219000)
# IGDB +  1  (offset 219500)
# IGDB +  1  (offset 220000)
# IGDB +  1  (offset 220500)
# IGDB +  1  (offset 221000)
# IGDB +  1  (offset 221500)
# IGDB +  1  (offset 222000)
# IGDB +  1  (offset 222500)
# IGDB +  1  (offset 223000)
# IGDB +  1  (offset 223500)
# IGDB +  1  (offset 224000)
# IGDB +  1  (offset 224500)
# IGDB +  1  (offset 225000)
# IGDB +  1  (offset 225500)
# IGDB +  1  (offset 226000)
# IGDB +  1  (offset 226500)
# IGDB +  1  (offset 227000)
# IGDB +  1  (offset 227500)
# IGDB +  1  (offset 228000)
# IGDB +  1  (offset 228500)
# IGDB +  1  (offset 229000)
# IGDB +  1  (offset 229500)
# IGDB +  1  (offset 230000)
# IGDB +  1  (offset 230500)
# IGDB +  1  (offset 231000)
# IGDB +  1  (offset 231500)
# IGDB +  1  (offset 232000)
# IGDB +  1  (offset 232500)
# IGDB +  1  (offset 233000)
# IGDB +  1  (offset 233500)
# IGDB +  1  (offset 234000)
# IGDB +  1  (offset 234500)
# IGDB +  1  (offset 235000)
# IGDB +  1  (offset 235500)
# IGDB +  1  (offset 236000)
# IGDB +  1  (offset 236500)
# IGDB +  1  (offset 237000)
# IGDB +  1  (offset 237500)
# IGDB +  1  (offset 238000)
# IGDB +  1  (offset 238500)
# IGDB +  1  (offset 239000)
# IGDB +  1  (offset 239500)
# IGDB +  1  (offset 240000)
# IGDB +  1  (offset 240500)
# IGDB +  1  (offset 241000)
# IGDB +  1  (offset 241500)
# IGDB +  1  (offset 242000)
# IGDB +  1  (offset 242500)
# IGDB +  1  (offset 243000)
# IGDB +  1  (offset 243500)
# IGDB +  1  (offset 244000)
# IGDB +  1  (offset 244500)
# IGDB +  1  (offset 245000)
# IGDB +  1  (offset 245500)
# IGDB +  1  (offset 246000)
# IGDB +  1  (offset 246500)
# IGDB +  1  (offset 247000)
# IGDB +  1  (offset 247500)
# IGDB +  1  (offset 248000)
# IGDB +  1  (offset 248500)
# IGDB +  1  (offset 249000)
# IGDB +  1  (offset 249500)
# IGDB +  1  (offset 250000)
# IGDB +  1  (offset 250500)
# IGDB +  1  (offset 251000)
# IGDB +  1  (offset 251500)
# IGDB +  1  (offset 252000)
# IGDB +  1  (offset 252500)
# IGDB +  1  (offset 253000)
# IGDB +  1  (offset 253500)
# IGDB +  1  (offset 254000)
# IGDB +  1  (offset 254500)
# IGDB +  1  (offset 255000)
# IGDB +  1  (offset 255500)
# IGDB +  1  (offset 256000)
# IGDB +  1  (offset 256500)
# IGDB +  1  (offset 257000)
# IGDB +  1  (offset 257500)
# IGDB +  1  (offset 258000)
# IGDB +  1  (offset 258500)
# IGDB +  1  (offset 259000)
# IGDB +  1  (offset 259500)
# IGDB +  1  (offset 260000)
# IGDB +  1  (offset 260500)
# IGDB +  1  (offset 261000)
# IGDB +  1  (offset 261500)
# IGDB +  1  (offset 262000)
# IGDB +  1  (offset 262500)
# IGDB +  1  (offset 263000)
# IGDB +  1  (offset 263500)
# IGDB +  1  (offset 264000)
# IGDB +  1  (offset 264500)
# IGDB +  1  (offset 265000)
# IGDB +  1  (offset 265500)
# IGDB +  1  (offset 266000)
# IGDB +  1  (offset 266500)
# IGDB +  1  (offset 267000)
# IGDB +  1  (offset 267500)
# IGDB +  1  (offset 268000)
# IGDB +  1  (offset 268500)
# IGDB +  1  (offset 269000)
# IGDB +  1  (offset 269500)
# IGDB +  1  (offset 270000)
# IGDB +  1  (offset 270500)
# IGDB +  1  (offset 271000)
# IGDB +  1  (offset 271500)
# IGDB +  1  (offset 272000)
# IGDB +  1  (offset 272500)
# IGDB +  1  (offset 273000)
# IGDB +  1  (offset 273500)
# IGDB +  1  (offset 274000)
# IGDB +  1  (offset 274500)
# IGDB +  1  (offset 275000)
# IGDB +  1  (offset 275500)
# IGDB +  1  (offset 276000)
# IGDB +  1  (offset 276500)
# IGDB +  1  (offset 277000)
# IGDB +  1  (offset 277500)
# IGDB +  1  (offset 278000)
# IGDB +  1  (offset 278500)
# IGDB +  1  (offset 279000)
# IGDB +  1  (offset 279500)
# IGDB +  1  (offset 280000)
# IGDB +  1  (offset 280500)
# IGDB +  1  (offset 281000)
# IGDB +  1  (offset 281500)
# IGDB +  1  (offset 282000)
# IGDB +  1  (offset 282500)
# IGDB +  1  (offset 283000)
# IGDB +  1  (offset 283500)
# IGDB +  1  (offset 284000)
# IGDB +  1  (offset 284500)
# IGDB +  1  (offset 285000)
# IGDB +  1  (offset 285500)
# IGDB +  1  (offset 286000)
# IGDB +  1  (offset 286500)
# IGDB +  1  (offset 287000)
# IGDB +  1  (offset 287500)
# IGDB +  1  (offset 288000)
# IGDB +  1  (offset 288500)
# IGDB +  1  (offset 289000)
# IGDB +  1  (offset 289500)
# IGDB +  1  (offset 290000)
# IGDB +  1  (offset 290500)
# IGDB +  1  (offset 291000)
# IGDB +  1  (offset 291500)
# IGDB +  1  (offset 292000)
# IGDB +  1  (offset 292500)
# IGDB +  1  (offset 293000)
# IGDB +  1  (offset 293500)
# IGDB +  1  (offset 294000)
# IGDB +  1  (offset 294500)
# IGDB +  1  (offset 295000)
# IGDB +  1  (offset 295500)
# IGDB +  1  (offset 296000)
# IGDB +  1  (offset 296500)
# IGDB +  1  (offset 297000)
# IGDB +  1  (offset 297500)
# IGDB +  1  (offset 298000)
# IGDB +  1  (offset 298500)
# IGDB +  1  (offset 299000)
# IGDB +  1  (offset 299500)
# IGDB +  1  (offset 300000)
# IGDB +  1  (offset 300500)
# IGDB +  1  (offset 301000)
# IGDB +  1  (offset 301500)
# IGDB +  1  (offset 302000)
# IGDB +  1  (offset 302500)
# IGDB +  1  (offset 303000)
# IGDB +  1  (offset 303500)
# IGDB +  1  (offset 304000)
# IGDB +  1  (offset 304500)
# IGDB +  1  (offset 305000)
# IGDB +  1  (offset 305500)
# IGDB +  1  (offset 306000)
# IGDB +  1  (offset 306500)
# IGDB +  1  (offset 307000)
# IGDB +  1  (offset 307500)
# IGDB +  1  (offset 308000)
# IGDB +  1  (offset 308500)
# IGDB +  1  (offset 309000)
# IGDB +  1  (offset 309500)
# IGDB +  1  (offset 310000)
# IGDB +  1  (offset 310500)
# IGDB +  1  (offset 311000)
# IGDB +  1  (offset 311500)
# IGDB +  1  (offset 312000)
# IGDB +  1  (offset 312500)
# IGDB +  1  (offset 313000)
# IGDB +  1  (offset 313500)
# IGDB +  1  (offset 314000)
# IGDB +  1  (offset 314500)
# IGDB +  1  (offset 315000)
# IGDB +  1  (offset 315500)
# IGDB +  1  (offset 316000)
# IGDB +  1  (offset 316500)
# IGDB +  1  (offset 317000)
# IGDB +  1  (offset 317500)
# IGDB +  1  (offset 318000)
# IGDB +  1  (offset 318500)
# IGDB +  1  (offset 319000)
# IGDB +  1  (offset 319500)
# IGDB +  1  (offset 320000)
# IGDB +  1  (offset 320500)
# IGDB +  1  (offset 321000)
# IGDB +  1  (offset 321500)
# IGDB +  1  (offset 322000)
# IGDB +  1  (offset 322500)
# IGDB +  1  (offset 323000)
# IGDB +  1  (offset 323500)
# IGDB +  1  (offset 324000)
# IGDB +  1  (offset 324500)
# IGDB +  1  (offset 325000)
# IGDB +  1  (offset 325500)
# IGDB +  1  (offset 326000)
# IGDB +  1  (offset 326500)
# IGDB +  1  (offset 327000)
# IGDB +  1  (offset 327500)
# IGDB +  1  (offset 328000)
# IGDB +  1  (offset 328500)
# IGDB +  1  (offset 329000)
# IGDB +  1  (offset 329500)
# IGDB +  1  (offset 330000)
# IGDB +  1  (offset 330500)
# IGDB +  1  (offset 331000)
# IGDB +  1  (offset 331500)
# IGDB +  1  (offset 332000)
# IGDB +  1  (offset 332500)
# IGDB +  1  (offset 333000)
# IGDB +  1  (offset 333500)
# IGDB +  1  (offset 334000)
# IGDB +  1  (offset 334500)
# IGDB +  1  (offset 335000)
# IGDB +  1  (offset 335500)
# IGDB +  1  (offset 336000)
# IGDB +  1  (offset 336500)
# IGDB +  1  (offset 337000)
# IGDB +  1  (offset 337500)
# IGDB +  1  (offset 338000)
# IGDB +  1  (offset 338500)
# IGDB +  1  (offset 339000)
# IGDB +  1  (offset 339500)
# IGDB +  1  (offset 340000)
# IGDB +  1  (offset 340500)
# IGDB +  1  (offset 341000)
# IGDB +  1  (offset 341500)
# IGDB +  1  (offset 342000)
# IGDB +  1  (offset 342500)
# IGDB +  1  (offset 343000)
# IGDB +  1  (offset 343500)
# IGDB +  1  (offset 344000)
# IGDB +  1  (offset 344500)
# IGDB +  1  (offset 345000)
# IGDB +  1  (offset 345500)
# IGDB +  1  (offset 346000)
# IGDB +  1  (offset 346500)
# IGDB +  1  (offset 347000)
# IGDB +  1  (offset 347500)
# IGDB +  1  (offset 348000)
# IGDB +  1  (offset 348500)
# IGDB +  1  (offset 349000)
# IGDB +  1  (offset 349500)
# IGDB +  1  (offset 350000)
# IGDB +  1  (offset 350500)
# IGDB +  1  (offset 351000)
# IGDB +  1  (offset 351500)
# IGDB +  1  (offset 352000)
# IGDB +  1  (offset 352500)
# IGDB +  1  (offset 353000)
# IGDB +  1  (offset 353500)
# IGDB +  1  (offset 354000)
# IGDB +  1  (offset 354500)
# IGDB +  1  (offset 355000)
# IGDB +  1  (offset 355500)
# IGDB +  1  (offset 356000)
# IGDB +  1  (offset 356500)
# IGDB +  1  (offset 357000)
# IGDB +  1  (offset 357500)
# IGDB +  1  (offset 358000)
# IGDB +  1  (offset 358500)
# IGDB +  1  (offset 359000)
# IGDB +  1  (offset 359500)
# IGDB +  1  (offset 360000)
# IGDB +  1  (offset 360500)
# IGDB +  1  (offset 361000)
# IGDB +  1  (offset 361500)
# IGDB +  1  (offset 362000)
# IGDB +  1  (offset 362500)
# IGDB +  1  (offset 363000)
# IGDB +  1  (offset 363500)
# IGDB +  1  (offset 364000)
# IGDB +  1  (offset 364500)
# IGDB +  1  (offset 365000)
# IGDB +  1  (offset 365500)
# IGDB +  1  (offset 366000)
# IGDB +  1  (offset 366500)
# IGDB +  1  (offset 367000)
# IGDB +  1  (offset 367500)
# IGDB +  1  (offset 368000)
# IGDB +  1  (offset 368500)
# IGDB +  1  (offset 369000)
# IGDB +  1  (offset 369500)
# IGDB +  1  (offset 370000)
# IGDB +  1  (offset 370500)
# IGDB +  1  (offset 371000)
# IGDB +  1  (offset 371500)
# IGDB +  1  (offset 372000)
# IGDB +  1  (offset 372500)
# IGDB +  1  (offset 373000)
# IGDB +  1  (offset 373500)
# IGDB +  1  (offset 374000)
# IGDB +  1  (offset 374500)
# IGDB +  1  (offset 375000)
# IGDB +  1  (offset 375500)
# IGDB +  1  (offset 376000)
# IGDB +  1  (offset 376500)
# IGDB +  1  (offset 377000)
# IGDB +  1  (offset 377500)
# IGDB +  1  (offset 378000)
# IGDB +  1  (offset 378500)
# IGDB +  1  (offset 379000)
# IGDB +  1  (offset 379500)
# IGDB +  1  (offset 380000)
# IGDB +  1  (offset 380500)
# IGDB +  1  (offset 381000)
# IGDB +  1  (offset 381500)
# IGDB +  1  (offset 382000)
# IGDB +  1  (offset 382500)
# IGDB +  1  (offset 383000)
# IGDB +  1  (offset 383500)
# IGDB +  1  (offset 384000)
# IGDB +  1  (offset 384500)
# IGDB +  1  (offset 385000)
# IGDB +  1  (offset 385500)
# IGDB +  1  (offset 386000)
# IGDB +  1  (offset 386500)
# IGDB +  1  (offset 387000)
# IGDB +  1  (offset 387500)
# IGDB +  1  (offset 388000)
# IGDB +  1  (offset 388500)
# IGDB +  1  (offset 389000)
# IGDB +  1  (offset 389500)
# IGDB +  1  (offset 390000)
# IGDB +  1  (offset 390500)
# IGDB +  1  (offset 391000)
# IGDB +  1  (offset 391500)
# IGDB +  1  (offset 392000)
# IGDB +  1  (offset 392500)
# IGDB +  1  (offset 393000)
# IGDB +  1  (offset 393500)
# IGDB +  1  (offset 394000)
# IGDB +  1  (offset 394500)
# IGDB +  1  (offset 395000)
# IGDB +  1  (offset 395500)
# IGDB +  1  (offset 396000)
# IGDB +  1  (offset 396500)
# IGDB +  1  (offset 397000)
# IGDB +  1  (offset 397500)
# IGDB +  1  (offset 398000)
# IGDB +  1  (offset 398500)
# IGDB +  1  (offset 399000)
# IGDB +  1  (offset 399500)
# IGDB +  1  (offset 400000)
# IGDB +  1  (offset 400500)
# IGDB +  1  (offset 401000)
# IGDB +  1  (offset 401500)
# IGDB +  1  (offset 402000)
# IGDB +  1  (offset 402500)
# IGDB +  1  (offset 403000)
# IGDB +  1  (offset 403500)
# IGDB +  1  (offset 404000)
# IGDB +  1  (offset 404500)
# IGDB +  1  (offset 405000)
# IGDB +  1  (offset 405500)
# IGDB +  1  (offset 406000)
# IGDB +  1  (offset 406500)
# IGDB +  1  (offset 407000)
# IGDB +  1  (offset 407500)
# IGDB +  1  (offset 408000)
# IGDB +  1  (offset 408500)
# IGDB +  1  (offset 409000)
# IGDB +  1  (offset 409500)
# IGDB +  1  (offset 410000)
# IGDB +  1  (offset 410500)
# IGDB +  1  (offset 411000)
# IGDB +  1  (offset 411500)
# IGDB +  1  (offset 412000)
# IGDB +  1  (offset 412500)
# IGDB +  1  (offset 413000)
# IGDB +  1  (offset 413500)
# IGDB +  1  (offset 414000)
# IGDB +  1  (offset 414500)
# IGDB +  1  (offset 415000)
# IGDB +  1  (offset 415500)
# IGDB +  1  (offset 416000)
# IGDB +  1  (offset 416500)
# IGDB +  1  (offset 417000)
# IGDB +  1  (offset 417500)
# IGDB +  1  (offset 418000)
# IGDB +  1  (offset 418500)
# IGDB +  1  (offset 419000)
# IGDB +  1  (offset 419500)
# IGDB +  1  (offset 420000)
# IGDB +  1  (offset 420500)
# IGDB +  1  (offset 421000)
# IGDB +  1  (offset 421500)
# IGDB +  1  (offset 422000)
# IGDB +  1  (offset 422500)
# IGDB +  1  (offset 423000)
# IGDB +  1  (offset 423500)
# IGDB +  1  (offset 424000)
# IGDB +  1  (offset 424500)
# IGDB +  1  (offset 425000)
# IGDB +  1  (offset 425500)
# IGDB +  1  (offset 426000)
# IGDB +  1  (offset 426500)
# IGDB +  1  (offset 427000)
# IGDB +  1  (offset 427500)
# IGDB +  1  (offset 428000)
# IGDB +  1  (offset 428500)
# IGDB +  1  (offset 429000)
# IGDB +  1  (offset 429500)
# IGDB +  1  (offset 430000)
# IGDB +  1  (offset 430500)
# IGDB +  1  (offset 431000)
# IGDB +  1  (offset 431500)
# IGDB +  1  (offset 432000)
# IGDB +  1  (offset 432500)
# IGDB +  1  (offset 433000)
# IGDB +  1  (offset 433500)
# IGDB +  1  (offset 434000)
# IGDB +  1  (offset 434500)
# IGDB +  1  (offset 435000)
# IGDB +  1  (offset 435500)
# IGDB +  1  (offset 436000)
# IGDB +  1  (offset 436500)
# IGDB +  1  (offset 437000)
# IGDB +  1  (offset 437500)
# IGDB +  1  (offset 438000)
# IGDB +  1  (offset 438500)
# IGDB +  1  (offset 439000)
# IGDB +  1  (offset 439500)
# IGDB +  1  (offset 440000)
# IGDB +  1  (offset 440500)
# IGDB +  1  (offset 441000)
# IGDB +  1  (offset 441500)
# IGDB +  1  (offset 442000)
# IGDB +  1  (offset 442500)
# IGDB +  1  (offset 443000)
# IGDB +  1  (offset 443500)
# IGDB +  1  (offset 444000)
# IGDB +  1  (offset 444500)
# IGDB +  1  (offset 445000)
# IGDB +  1  (offset 445500)
# IGDB +  1  (offset 446000)
# IGDB +  1  (offset 446500)
# IGDB +  1  (offset 447000)
# IGDB +  1  (offset 447500)
# IGDB +  1  (offset 448000)
# IGDB +  1  (offset 448500)
# IGDB +  1  (offset 449000)
# IGDB +  1  (offset 449500)
# IGDB +  1  (offset 450000)
# IGDB +  1  (offset 450500)
# IGDB +  1  (offset 451000)
# IGDB +  1  (offset 451500)
# IGDB +  1  (offset 452000)
# IGDB +  1  (offset 452500)
# IGDB +  1  (offset 453000)
# IGDB +  1  (offset 453500)
# IGDB +  1  (offset 454000)
# IGDB +  1  (offset 454500)
# IGDB +  1  (offset 455000)
# IGDB +  1  (offset 455500)
# IGDB +  1  (offset 456000)
# IGDB +  1  (offset 456500)
# IGDB +  1  (offset 457000)
# IGDB +  1  (offset 457500)
# IGDB +  1  (offset 458000)
# IGDB +  1  (offset 458500)
# IGDB +  1  (offset 459000)
# IGDB +  1  (offset 459500)
# IGDB +  1  (offset 460000)
# IGDB +  1  (offset 460500)
# IGDB +  1  (offset 461000)
# IGDB +  1  (offset 461500)
# IGDB +  1  (offset 462000)
# IGDB +  1  (offset 462500)
# IGDB +  1  (offset 463000)
# IGDB +  1  (offset 463500)
# IGDB +  1  (offset 464000)
# IGDB +  1  (offset 464500)
# IGDB +  1  (offset 465000)
# IGDB +  1  (offset 465500)
# IGDB +  1  (offset 466000)
# IGDB +  1  (offset 466500)
# IGDB +  1  (offset 467000)
# IGDB +  1  (offset 467500)
# IGDB +  1  (offset 468000)
# IGDB +  1  (offset 468500)
# IGDB +  1  (offset 469000)
# IGDB +  1  (offset 469500)
# IGDB +  1  (offset 470000)
# IGDB +  1  (offset 470500)
# IGDB +  1  (offset 471000)
# IGDB +  1  (offset 471500)
# IGDB +  1  (offset 472000)
# IGDB +  1  (offset 472500)
# IGDB +  1  (offset 473000)
# IGDB +  1  (offset 473500)
# IGDB +  1  (offset 474000)
# IGDB +  1  (offset 474500)
# IGDB +  1  (offset 475000)
# IGDB +  1  (offset 475500)
# IGDB +  1  (offset 476000)
# IGDB +  1  (offset 476500)
# IGDB +  1  (offset 477000)
# IGDB +  1  (offset 477500)
# IGDB +  1  (offset 478000)
# IGDB +  1  (offset 478500)
# IGDB +  1  (offset 479000)
# IGDB +  1  (offset 479500)
# IGDB +  1  (offset 480000)
# IGDB +  1  (offset 480500)
# IGDB +  1  (offset 481000)
# IGDB +  1  (offset 481500)
# IGDB +  1  (offset 482000)
# IGDB +  1  (offset 482500)
# IGDB +  1  (offset 483000)
# IGDB +  1  (offset 483500)
# IGDB +  1  (offset 484000)
# IGDB +  1  (offset 484500)
# IGDB +  1  (offset 485000)
# IGDB +  1  (offset 485500)
# IGDB +  1  (offset 486000)
# IGDB +  1  (offset 486500)
# IGDB +  1  (offset 487000)
# IGDB +  1  (offset 487500)
# IGDB +  1  (offset 488000)
# IGDB +  1  (offset 488500)
# IGDB +  1  (offset 489000)
# IGDB +  1  (offset 489500)
# IGDB +  1  (offset 490000)
# IGDB +  1  (offset 490500)
# IGDB +  1  (offset 491000)
# IGDB +  1  (offset 491500)
# IGDB +  1  (offset 492000)
# IGDB +  1  (offset 492500)
# IGDB +  1  (offset 493000)
# IGDB +  1  (offset 493500)
# IGDB +  1  (offset 494000)
# IGDB +  1  (offset 494500)
# IGDB +  1  (offset 495000)
# IGDB +  1  (offset 495500)
# IGDB +  1  (offset 496000)
# IGDB +  1  (offset 496500)
# IGDB +  1  (offset 497000)
# IGDB +  1  (offset 497500)
# IGDB +  1  (offset 498000)
# IGDB +  1  (offset 498500)
# IGDB +  1  (offset 499000)
# IGDB +  1  (offset 499500)
# IGDB +  1  (offset 500000)
# IGDB +  1  (offset 500500)
# IGDB +  1  (offset 501000)
# IGDB +  1  (offset 501500)
# IGDB +  1  (offset 502000)
# IGDB +  1  (offset 502500)
# IGDB +  1  (offset 503000)
# IGDB +  1  (offset 503500)
# IGDB +  1  (offset 504000)
# IGDB +  1  (offset 504500)
# IGDB +  1  (offset 505000)
# IGDB +  1  (offset 505500)
# IGDB +  1  (offset 506000)
# IGDB +  1  (offset 506500)
# IGDB +  1  (offset 507000)
# IGDB +  1  (offset 507500)
# IGDB +  1  (offset 508000)
# IGDB +  1  (offset 508500)
# IGDB +  1  (offset 509000)
# IGDB +  1  (offset 509500)
# IGDB +  1  (offset 510000)
# IGDB +  1  (offset 510500)
# IGDB +  1  (offset 511000)
# IGDB +  1  (offset 511500)
# IGDB +  1  (offset 512000)
# IGDB +  1  (offset 512500)
# IGDB +  1  (offset 513000)
# IGDB +  1  (offset 513500)
# IGDB +  1  (offset 514000)
# IGDB +  1  (offset 514500)
# IGDB +  1  (offset 515000)
# IGDB +  1  (offset 515500)
# IGDB +  1  (offset 516000)
# IGDB +  1  (offset 516500)
# IGDB +  1  (offset 517000)
# IGDB +  1  (offset 517500)
# IGDB +  1  (offset 518000)
# IGDB +  1  (offset 518500)
# IGDB +  1  (offset 519000)
# IGDB +  1  (offset 519500)
# IGDB +  1  (offset 520000)
# IGDB +  1  (offset 520500)
# IGDB +  1  (offset 521000)
# IGDB +  1  (offset 521500)
# IGDB +  1  (offset 522000)
# IGDB +  1  (offset 522500)
# IGDB +  1  (offset 523000)
# IGDB +  1  (offset 523500)
# IGDB +  1  (offset 524000)
# IGDB +  1  (offset 524500)
# IGDB +  1  (offset 525000)
# IGDB +  1  (offset 525500)
# IGDB +  1  (offset 526000)
# IGDB +  1  (offset 526500)
# IGDB +  1  (offset 527000)
# IGDB +  1  (offset 527500)
# IGDB +  1  (offset 528000)
# IGDB +  1  (offset 528500)
# IGDB +  1  (offset 529000)
# IGDB +  1  (offset 529500)
# IGDB +  1  (offset 530000)
# IGDB +  1  (offset 530500)
# IGDB +  1  (offset 531000)
# IGDB +  1  (offset 531500)
# IGDB +  1  (offset 532000)
# IGDB +  1  (offset 532500)
# IGDB +  1  (offset 533000)
# IGDB +  1  (offset 533500)
# IGDB +  1  (offset 534000)
# IGDB +  1  (offset 534500)
# IGDB +  1  (offset 535000)
# IGDB +  1  (offset 535500)
# IGDB +  1  (offset 536000)
# IGDB +  1  (offset 536500)
# IGDB +  1  (offset 537000)
# IGDB +  1  (offset 537500)
# IGDB +  1  (offset 538000)
# IGDB +  1  (offset 538500)
# IGDB +  1  (offset 539000)
# IGDB +  1  (offset 539500)
# IGDB +  1  (offset 540000)
# IGDB +  1  (offset 540500)
# IGDB +  1  (offset 541000)
# IGDB +  1  (offset 541500)
# IGDB +  1  (offset 542000)
# IGDB +  1  (offset 542500)
# IGDB +  1  (offset 543000)
# IGDB +  1  (offset 543500)
# IGDB +  1  (offset 544000)
# IGDB +  1  (offset 544500)
# IGDB +  1  (offset 545000)
# IGDB +  1  (offset 545500)
# IGDB +  1  (offset 546000)
# IGDB +  1  (offset 546500)
# IGDB +  1  (offset 547000)
# IGDB +  1  (offset 547500)
# IGDB +  1  (offset 548000)
# IGDB +  1  (offset 548500)
# IGDB +  1  (offset 549000)
# IGDB +  1  (offset 549500)
# IGDB +  1  (offset 550000)
# IGDB +  1  (offset 550500)
# IGDB +  1  (offset 551000)
# IGDB +  1  (offset 551500)
# IGDB +  1  (offset 552000)
# IGDB +  1  (offset 552500)
# IGDB +  1  (offset 553000)
# IGDB +  1  (offset 553500)
# IGDB +  1  (offset 554000)
# IGDB +  1  (offset 554500)
# IGDB +  1  (offset 555000)
# IGDB +  1  (offset 555500)
# IGDB +  1  (offset 556000)
# IGDB +  1  (offset 556500)
# IGDB +  1  (offset 557000)
# IGDB +  1  (offset 557500)
# IGDB +  1  (offset 558000)
# IGDB +  1  (offset 558500)
# IGDB +  1  (offset 559000)
# IGDB +  1  (offset 559500)
# IGDB +  1  (offset 560000)
# IGDB +  1  (offset 560500)
# IGDB +  1  (offset 561000)
# IGDB +  1  (offset 561500)
# IGDB +  1  (offset 562000)
# IGDB +  1  (offset 562500)
# IGDB +  1  (offset 563000)
# IGDB +  1  (offset 563500)
# IGDB +  1  (offset 564000)
# IGDB +  1  (offset 564500)
# IGDB +  1  (offset 565000)
# IGDB +  1  (offset 565500)
# IGDB +  1  (offset 566000)
# IGDB +  1  (offset 566500)
# IGDB +  1  (offset 567000)
# IGDB +  1  (offset 567500)
# IGDB +  1  (offset 568000)
# IGDB +  1  (offset 568500)
# IGDB +  1  (offset 569000)
# IGDB +  1  (offset 569500)
# IGDB +  1  (offset 570000)
# IGDB +  1  (offset 570500)
# IGDB +  1  (offset 571000)
# IGDB +  1  (offset 571500)
# IGDB +  1  (offset 572000)
# IGDB +  1  (offset 572500)
# IGDB +  1  (offset 573000)
# IGDB +  1  (offset 573500)
# IGDB +  1  (offset 574000)
# IGDB +  1  (offset 574500)
# IGDB +  1  (offset 575000)
# IGDB +  1  (offset 575500)
# IGDB +  1  (offset 576000)
# IGDB +  1  (offset 576500)
# IGDB +  1  (offset 577000)
# IGDB +  1  (offset 577500)
# IGDB +  1  (offset 578000)
# IGDB +  1  (offset 578500)
# IGDB +  1  (offset 579000)
# IGDB +  1  (offset 579500)
# IGDB +  1  (offset 580000)
# IGDB +  1  (offset 580500)
# IGDB +  1  (offset 581000)
# IGDB +  1  (offset 581500)
# IGDB +  1  (offset 582000)
# IGDB +  1  (offset 582500)
# IGDB +  1  (offset 583000)
# IGDB +  1  (offset 583500)
# IGDB +  1  (offset 584000)
# IGDB +  1  (offset 584500)
# IGDB +  1  (offset 585000)
# IGDB +  1  (offset 585500)
# IGDB +  1  (offset 586000)
# IGDB +  1  (offset 586500)
# IGDB +  1  (offset 587000)
# IGDB +  1  (offset 587500)
# IGDB +  1  (offset 588000)
# IGDB +  1  (offset 588500)
# IGDB +  1  (offset 589000)
# IGDB +  1  (offset 589500)
# IGDB +  1  (offset 590000)
# IGDB +  1  (offset 590500)
# IGDB +  1  (offset 591000)
# IGDB +  1  (offset 591500)
# IGDB +  1  (offset 592000)
# IGDB +  1  (offset 592500)
# IGDB +  1  (offset 593000)
# IGDB +  1  (offset 593500)
# IGDB +  1  (offset 594000)
# IGDB +  1  (offset 594500)
# IGDB +  1  (offset 595000)
# IGDB +  1  (offset 595500)
# IGDB +  1  (offset 596000)
# IGDB +  1  (offset 596500)
# IGDB +  1  (offset 597000)
# IGDB +  1  (offset 597500)
# IGDB +  1  (offset 598000)
# IGDB +  1  (offset 598500)
# IGDB +  1  (offset 599000)
# IGDB +  1  (offset 599500)
# IGDB +  1  (offset 600000)
# IGDB +  1  (offset 600500)
# IGDB +  1  (offset 601000)
# IGDB +  1  (offset 601500)
# IGDB +  1  (offset 602000)
# IGDB +  1  (offset 602500)
# IGDB +  1  (offset 603000)
# IGDB +  1  (offset 603500)
# IGDB +  1  (offset 604000)
# IGDB +  1  (offset 604500)
# IGDB +  1  (offset 605000)
# IGDB +  1  (offset 605500)
# IGDB +  1  (offset 606000)
# IGDB +  1  (offset 606500)
# IGDB +  1  (offset 607000)
# IGDB +  1  (offset 607500)
# IGDB +  1  (offset 608000)
# IGDB +  1  (offset 608500)
# IGDB +  1  (offset 609000)
# IGDB +  1  (offset 609500)
# IGDB +  1  (offset 610000)
# IGDB +  1  (offset 610500)
# IGDB +  1  (offset 611000)
# IGDB +  1  (offset 611500)
# IGDB +  1  (offset 612000)
# IGDB +  1  (offset 612500)
# IGDB +  1  (offset 613000)
# IGDB +  1  (offset 613500)
# IGDB +  1  (offset 614000)
# IGDB +  1  (offset 614500)
# IGDB +  1  (offset 615000)
# IGDB +  1  (offset 615500)
# IGDB +  1  (offset 616000)
# IGDB +  1  (offset 616500)
# IGDB +  1  (offset 617000)
# IGDB +  1  (offset 617500)
# IGDB +  1  (offset 618000)
# IGDB +  1  (offset 618500)
# IGDB +  1  (offset 619000)
# IGDB +  1  (offset 619500)
# IGDB +  1  (offset 620000)
# IGDB +  1  (offset 620500)
# IGDB +  1  (offset 621000)
# IGDB +  1  (offset 621500)
# IGDB +  1  (offset 622000)
# IGDB +  1  (offset 622500)
# IGDB +  1  (offset 623000)
# IGDB +  1  (offset 623500)
# IGDB +  1  (offset 624000)
# IGDB +  1  (offset 624500)
# IGDB +  1  (offset 625000)
# IGDB +  1  (offset 625500)
# IGDB +  1  (offset 626000)
# IGDB +  1  (offset 626500)
# IGDB +  1  (offset 627000)
# IGDB +  1  (offset 627500)
# IGDB +  1  (offset 628000)
# IGDB +  1  (offset 628500)
# IGDB +  1  (offset 629000)
# IGDB +  1  (offset 629500)
# IGDB +  1  (offset 630000)
# IGDB +  1  (offset 630500)
# IGDB +  1  (offset 631000)
# IGDB +  1  (offset 631500)
# IGDB +  1  (offset 632000)
# IGDB +  1  (offset 632500)
# IGDB +  1  (offset 633000)
# IGDB +  1  (offset 633500)
# IGDB +  1  (offset 634000)
# IGDB +  1  (offset 634500)
# IGDB +  1  (offset 635000)
# IGDB +  1  (offset 635500)
# IGDB +  1  (offset 636000)
# IGDB +  1  (offset 636500)
# IGDB +  1  (offset 637000)
# IGDB +  1  (offset 637500)
# IGDB +  1  (offset 638000)
# IGDB +  1  (offset 638500)
# IGDB +  1  (offset 639000)
# IGDB +  1  (offset 639500)
# IGDB +  1  (offset 640000)
# IGDB +  1  (offset 640500)
# IGDB +  1  (offset 641000)
# IGDB +  1  (offset 641500)
# IGDB +  1  (offset 642000)
# IGDB +  1  (offset 642500)
# IGDB +  1  (offset 643000)
# IGDB +  1  (offset 643500)
# IGDB +  1  (offset 644000)
# IGDB +  1  (offset 644500)
# IGDB +  1  (offset 645000)
# IGDB +  1  (offset 645500)
# IGDB +  1  (offset 646000)
# IGDB +  1  (offset 646500)
# IGDB +  1  (offset 647000)
# IGDB +  1  (offset 647500)
# IGDB +  1  (offset 648000)
# IGDB +  1  (offset 648500)
# IGDB +  1  (offset 649000)
# IGDB +  1  (offset 649500)
# IGDB +  1  (offset 650000)
# IGDB +  1  (offset 650500)
# IGDB +  1  (offset 651000)
# IGDB +  1  (offset 651500)
# IGDB +  1  (offset 652000)
# IGDB +  1  (offset 652500)
# IGDB +  1  (offset 653000)
# IGDB +  1  (offset 653500)
# IGDB +  1  (offset 654000)
# IGDB +  1  (offset 654500)
# IGDB +  1  (offset 655000)
# IGDB +  1  (offset 655500)
# IGDB +  1  (offset 656000)
# IGDB +  1  (offset 656500)
# IGDB +  1  (offset 657000)
# IGDB +  1  (offset 657500)
# IGDB +  1  (offset 658000)
# IGDB +  1  (offset 658500)
# IGDB +  1  (offset 659000)
# IGDB +  1  (offset 659500)
# IGDB +  1  (offset 660000)
# IGDB +  1  (offset 660500)
# IGDB +  1  (offset 661000)
# IGDB +  1  (offset 661500)
# IGDB +  1  (offset 662000)
# IGDB +  1  (offset 662500)
# IGDB +  1  (offset 663000)
# IGDB +  1  (offset 663500)
# IGDB +  1  (offset 664000)
# IGDB +  1  (offset 664500)
# IGDB +  1  (offset 665000)
# IGDB +  1  (offset 665500)
# IGDB +  1  (offset 666000)
# IGDB +  1  (offset 666500)
# IGDB +  1  (offset 667000)
# IGDB +  1  (offset 667500)
# IGDB +  1  (offset 668000)
# IGDB +  1  (offset 668500)
# IGDB +  1  (offset 669000)
# IGDB +  1  (offset 669500)
# IGDB +  1  (offset 670000)
# IGDB +  1  (offset 670500)
# IGDB +  1  (offset 671000)
# IGDB +  1  (offset 671500)
# IGDB +  1  (offset 672000)
# IGDB +  1  (offset 672500)
# IGDB +  1  (offset 673000)
# IGDB +  1  (offset 673500)
# IGDB +  1  (offset 674000)
# IGDB +  1  (offset 674500)
# IGDB +  1  (offset 675000)
# IGDB +  1  (offset 675500)
# IGDB +  1  (offset 676000)
# IGDB +  1  (offset 676500)
# IGDB +  1  (offset 677000)
# IGDB +  1  (offset 677500)
# IGDB +  1  (offset 678000)
# IGDB +  1  (offset 678500)
# IGDB +  1  (offset 679000)
# IGDB +  1  (offset 679500)
# IGDB +  1  (offset 680000)
# IGDB +  1  (offset 680500)
# IGDB +  1  (offset 681000)
# IGDB +  1  (offset 681500)
# IGDB +  1  (offset 682000)
# IGDB +  1  (offset 682500)
# IGDB +  1  (offset 683000)
# IGDB +  1  (offset 683500)
# IGDB +  1  (offset 684000)
# IGDB +  1  (offset 684500)
# IGDB +  1  (offset 685000)
# IGDB +  1  (offset 685500)
# IGDB +  1  (offset 686000)
# IGDB +  1  (offset 686500)
# IGDB +  1  (offset 687000)
# IGDB +  1  (offset 687500)
# IGDB +  1  (offset 688000)
# IGDB +  1  (offset 688500)
# IGDB +  1  (offset 689000)
# IGDB +  1  (offset 689500)
# IGDB +  1  (offset 690000)
# IGDB +  1  (offset 690500)
# IGDB +  1  (offset 691000)
# IGDB +  1  (offset 691500)
# IGDB +  1  (offset 692000)
# IGDB +  1  (offset 692500)
# IGDB +  1  (offset 693000)
# IGDB +  1  (offset 693500)
# IGDB +  1  (offset 694000)
# IGDB +  1  (offset 694500)
# IGDB +  1  (offset 695000)
# IGDB +  1  (offset 695500)
# IGDB +  1  (offset 696000)
# IGDB +  1  (offset 696500)
# IGDB +  1  (offset 697000)
# IGDB +  1  (offset 697500)
# IGDB +  1  (offset 698000)
# IGDB +  1  (offset 698500)
# IGDB +  1  (offset 699000)
# IGDB +  1  (offset 699500)
# IGDB +  1  (offset 700000)
# IGDB +  1  (offset 700500)
# IGDB +  1  (offset 701000)
# IGDB +  1  (offset 701500)
# IGDB +  1  (offset 702000)
# IGDB +  1  (offset 702500)
# IGDB +  1  (offset 703000)
# IGDB +  1  (offset 703500)
# IGDB +  1  (offset 704000)
# IGDB +  1  (offset 704500)
# IGDB +  1  (offset 705000)
# IGDB +  1  (offset 705500)
# IGDB +  1  (offset 706000)
# IGDB +  1  (offset 706500)
# IGDB +  1  (offset 707000)
# IGDB +  1  (offset 707500)
# IGDB +  1  (offset 708000)
# IGDB +  1  (offset 708500)
# IGDB +  1  (offset 709000)
# IGDB +  1  (offset 709500)
# IGDB +  1  (offset 710000)
# IGDB +  1  (offset 710500)
# IGDB +  1  (offset 711000)
# IGDB +  1  (offset 711500)
# IGDB +  1  (offset 712000)
# IGDB +  1  (offset 712500)
# IGDB +  1  (offset 713000)
# IGDB +  1  (offset 713500)
# IGDB +  1  (offset 714000)
# IGDB +  1  (offset 714500)
# IGDB +  1  (offset 715000)
# IGDB +  1  (offset 715500)
# IGDB +  1  (offset 716000)
# IGDB +  1  (offset 716500)
# IGDB +  1  (offset 717000)
# IGDB +  1  (offset 717500)
# IGDB +  1  (offset 718000)
# IGDB +  1  (offset 718500)
# IGDB +  1  (offset 719000)
# IGDB +  1  (offset 719500)
# IGDB +  1  (offset 720000)
# IGDB +  1  (offset 720500)
# IGDB +  1  (offset 721000)
# IGDB +  1  (offset 721500)
# IGDB +  1  (offset 722000)
# IGDB +  1  (offset 722500)
# IGDB +  1  (offset 723000)
# IGDB +  1  (offset 723500)
# IGDB +  1  (offset 724000)
# IGDB +  1  (offset 724500)
# IGDB +  1  (offset 725000)
# IGDB +  1  (offset 725500)
# IGDB +  1  (offset 726000)
# IGDB +  1  (offset 726500)
# IGDB +  1  (offset 727000)
# IGDB +  1  (offset 727500)
# IGDB +  1  (offset 728000)
# IGDB +  1  (offset 728500)
# IGDB +  1  (offset 729000)
# IGDB +  1  (offset 729500)
# IGDB +  1  (offset 730000)
# IGDB +  1  (offset 730500)
# IGDB +  1  (offset 731000)
# IGDB +  1  (offset 731500)
# IGDB +  1  (offset 732000)
# IGDB +  1  (offset 732500)
# IGDB +  1  (offset 733000)
# IGDB +  1  (offset 733500)
# IGDB +  1  (offset 734000)
# IGDB +  1  (offset 734500)
# IGDB +  1  (offset 735000)
# IGDB +  1  (offset 735500)
# IGDB +  1  (offset 736000)
# IGDB +  1  (offset 736500)
# IGDB +  1  (offset 737000)
# IGDB +  1  (offset 737500)
# IGDB +  1  (offset 738000)
# IGDB +  1  (offset 738500)
# IGDB +  1  (offset 739000)
# IGDB +  1  (offset 739500)
# IGDB +  1  (offset 740000)
# IGDB +  1  (offset 740500)
# IGDB +  1  (offset 741000)
# IGDB +  1  (offset 741500)
# IGDB +  1  (offset 742000)
# IGDB +  1  (offset 742500)
# IGDB +  1  (offset 743000)
# IGDB +  1  (offset 743500)
# IGDB +  1  (offset 744000)
# IGDB +  1  (offset 744500)
# IGDB +  1  (offset 745000)
# IGDB +  1  (offset 745500)
# IGDB +  1  (offset 746000)
# IGDB +  1  (offset 746500)
# IGDB +  1  (offset 747000)
# IGDB +  1  (offset 747500)
# IGDB +  1  (offset 748000)
# IGDB +  1  (offset 748500)
# IGDB +  1  (offset 749000)
# IGDB +  1  (offset 749500)
# IGDB +  1  (offset 750000)
# IGDB +  1  (offset 750500)
# IGDB +  1  (offset 751000)
# IGDB +  1  (offset 751500)
# IGDB +  1  (offset 752000)
# IGDB +  1  (offset 752500)
# IGDB +  1  (offset 753000)
# IGDB +  1  (offset 753500)
# IGDB +  1  (offset 754000)
# IGDB +  1  (offset 754500)
# IGDB +  1  (offset 755000)
# IGDB +  1  (offset 755500)
# IGDB +  1  (offset 756000)
# IGDB +  1  (offset 756500)
# IGDB +  1  (offset 757000)
# IGDB +  1  (offset 757500)
# IGDB +  1  (offset 758000)
# IGDB +  1  (offset 758500)
# IGDB +  1  (offset 759000)
# IGDB +  1  (offset 759500)
# IGDB +  1  (offset 760000)
# IGDB +  1  (offset 760500)
# IGDB +  1  (offset 761000)
# IGDB +  1  (offset 761500)
# IGDB +  1  (offset 762000)
# IGDB +  1  (offset 762500)
# IGDB +  1  (offset 763000)
# IGDB +  1  (offset 763500)
# IGDB +  1  (offset 764000)
# IGDB +  1  (offset 764500)
# IGDB +  1  (offset 765000)
# IGDB +  1  (offset 765500)
# IGDB +  1  (offset 766000)
# IGDB +  1  (offset 766500)
# IGDB +  1  (offset 767000)
# IGDB +  1  (offset 767500)
# IGDB +  1  (offset 768000)
# IGDB +  1  (offset 768500)
# IGDB +  1  (offset 769000)
# IGDB +  1  (offset 769500)
# IGDB +  1  (offset 770000)
# IGDB +  1  (offset 770500)
# IGDB +  1  (offset 771000)
# IGDB +  1  (offset 771500)
# IGDB +  1  (offset 772000)
# IGDB +  1  (offset 772500)
# IGDB +  1  (offset 773000)
# IGDB +  1  (offset 773500)
# IGDB +  1  (offset 774000)
# IGDB +  1  (offset 774500)
# IGDB +  1  (offset 775000)
# IGDB +  1  (offset 775500)
# IGDB +  1  (offset 776000)
# IGDB +  1  (offset 776500)
# IGDB +  1  (offset 777000)
# IGDB +  1  (offset 777500)
# IGDB +  1  (offset 778000)
# IGDB +  1  (offset 778500)
# IGDB +  1  (offset 779000)
# IGDB +  1  (offset 779500)
# IGDB +  1  (offset 780000)
# IGDB +  1  (offset 780500)
# IGDB +  1  (offset 781000)
# IGDB +  1  (offset 781500)
# IGDB +  1  (offset 782000)
# IGDB +  1  (offset 782500)
# IGDB +  1  (offset 783000)
# IGDB +  1  (offset 783500)
# IGDB +  1  (offset 784000)
# IGDB +  1  (offset 784500)
# IGDB +  1  (offset 785000)
# IGDB +  1  (offset 785500)
# IGDB +  1  (offset 786000)
# IGDB +  1  (offset 786500)
# IGDB +  1  (offset 787000)
# IGDB +  1  (offset 787500)
# IGDB +  1  (offset 788000)
# IGDB +  1  (offset 788500)
# IGDB +  1  (offset 789000)
# IGDB +  1  (offset 789500)
# IGDB +  1  (offset 790000)
# IGDB +  1  (offset 790500)
# IGDB +  1  (offset 791000)
# IGDB +  1  (offset 791500)
# IGDB +  1  (offset 792000)
# IGDB +  1  (offset 792500)
# IGDB +  1  (offset 793000)
# IGDB +  1  (offset 793500)
# IGDB +  1  (offset 794000)
# IGDB +  1  (offset 794500)
# IGDB +  1  (offset 795000)
# IGDB +  1  (offset 795500)
# IGDB +  1  (offset 796000)
# IGDB +  1  (offset 796500)
# IGDB +  1  (offset 797000)
# IGDB +  1  (offset 797500)
# IGDB +  1  (offset 798000)
# IGDB +  1  (offset 798500)
# IGDB +  1  (offset 799000)
# IGDB +  1  (offset 799500)
# IGDB +  1  (offset 800000)
# IGDB +  1  (offset 800500)
# IGDB +  1  (offset 801000)
# IGDB +  1  (offset 801500)
# IGDB +  1  (offset 802000)
# IGDB +  1  (offset 802500)
# IGDB +  1  (offset 803000)
# IGDB +  1  (offset 803500)
# IGDB +  1  (offset 804000)
# IGDB +  1  (offset 804500)
# IGDB +  1  (offset 805000)
# IGDB +  1  (offset 805500)
# IGDB +  1  (offset 806000)
# IGDB +  1  (offset 806500)
# IGDB +  1  (offset 807000)
# IGDB +  1  (offset 807500)
# IGDB +  1  (offset 808000)
# IGDB +  1  (offset 808500)
# IGDB +  1  (offset 809000)
# IGDB +  1  (offset 809500)
# IGDB +  1  (offset 810000)
# IGDB +  1  (offset 810500)
# IGDB +  1  (offset 811000)
# IGDB +  1  (offset 811500)
# IGDB +  1  (offset 812000)
# IGDB +  1  (offset 812500)
# IGDB +  1  (offset 813000)
# IGDB +  1  (offset 813500)
# IGDB +  1  (offset 814000)
# IGDB +  1  (offset 814500)
# IGDB +  1  (offset 815000)
# IGDB +  1  (offset 815500)
# IGDB +  1  (offset 816000)
# IGDB +  1  (offset 816500)
# IGDB +  1  (offset 817000)
# IGDB +  1  (offset 817500)
# IGDB +  1  (offset 818000)
# IGDB +  1  (offset 818500)
# IGDB +  1  (offset 819000)
# IGDB +  1  (offset 819500)
# IGDB +  1  (offset 820000)
# IGDB +  1  (offset 820500)
# IGDB +  1  (offset 821000)
# IGDB +  1  (offset 821500)
# IGDB +  1  (offset 822000)
# IGDB +  1  (offset 822500)
# IGDB +  1  (offset 823000)
# IGDB +  1  (offset 823500)
# IGDB +  1  (offset 824000)
# IGDB +  1  (offset 824500)
# IGDB +  1  (offset 825000)
# IGDB +  1  (offset 825500)
# IGDB +  1  (offset 826000)
# IGDB +  1  (offset 826500)
# IGDB +  1  (offset 827000)
# IGDB +  1  (offset 827500)
# IGDB +  1  (offset 828000)
# IGDB +  1  (offset 828500)
# IGDB +  1  (offset 829000)
# IGDB +  1  (offset 829500)
# IGDB +  1  (offset 830000)
# IGDB +  1  (offset 830500)
# IGDB +  1  (offset 831000)
# IGDB +  1  (offset 831500)
# IGDB +  1  (offset 832000)
# IGDB +  1  (offset 832500)
# IGDB +  1  (offset 833000)
# IGDB +  1  (offset 833500)
# IGDB +  1  (offset 834000)
# IGDB +  1  (offset 834500)
# IGDB +  1  (offset 835000)
# IGDB +  1  (offset 835500)
# IGDB +  1  (offset 836000)
# IGDB +  1  (offset 836500)
# IGDB +  1  (offset 837000)
# IGDB +  1  (offset 837500)
# IGDB +  1  (offset 838000)
# IGDB +  1  (offset 838500)
# IGDB +  1  (offset 839000)
# IGDB +  1  (offset 839500)
# IGDB +  1  (offset 840000)
# IGDB +  1  (offset 840500)
# IGDB +  1  (offset 841000)
# IGDB +  1  (offset 841500)
# IGDB +  1  (offset 842000)
# IGDB +  1  (offset 842500)
# IGDB +  1  (offset 843000)
# IGDB +  1  (offset 843500)
# IGDB +  1  (offset 844000)
# IGDB +  1  (offset 844500)
# IGDB +  1  (offset 845000)
# IGDB +  1  (offset 845500)
# IGDB +  1  (offset 846000)
# IGDB +  1  (offset 846500)
# IGDB +  1  (offset 847000)
# IGDB +  1  (offset 847500)
# IGDB +  1  (offset 848000)
# IGDB +  1  (offset 848500)
# IGDB +  1  (offset 849000)

# %% [markdown]
# ## 5. Exploración básica (EDA)
